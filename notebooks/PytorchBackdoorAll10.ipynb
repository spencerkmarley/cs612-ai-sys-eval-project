# %%
import os
import pathlib
import torch

from torch import nn

from torch.utils.data import TensorDataset, DataLoader, Dataset
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import cv2 
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Class names for different classes
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
class CIFAR10Net(nn.Module):
    # from https://www.kaggle.com/code/shadabhussain/cifar-10-cnn-using-pytorch
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(2, 2) # output: 64 x 16 x 16

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2) # output: 128 x 8 x 8

        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2) # output: 256 x 4 x 4

        self.fc1 = nn.Linear(256 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)
        
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool1(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.pool2(x)

        x = self.conv5(x)
        x = F.relu(x)
        x = self.conv6(x)
        x = F.relu(x)
        x = self.pool3(x)

        x = torch.flatten(x, 1)        
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)

        output = x
        return output

# %%
def save_model(model, name):
    p = pathlib.Path(name)
    if not os.path.exists(p.parent):
        os.makedirs(p.parent, exist_ok=True)
    torch.save(model.state_dict(), name)

def load_model(model_class, name):
    model = model_class()
    model.load_state_dict(torch.load(name))

    return model

def train(model, dataloader, loss_fn, optimizer, device):
    size = len(dataloader.dataset)
    model.train()

    for batch, (x, y) in enumerate(dataloader):
        x, y = x.to(device), y.to(device)

        # Compute prediction error
        pred = model(x)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(x)
            print('loss: {:.4f} [{}/{}]'.format(loss, current, size))

    
def test(model, dataloader, loss_fn, device):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.to(device)
    model.eval()
    loss, correct = 0.0, 0
    
    with torch.no_grad():
        for x, y in dataloader:
            x, y = x.to(device), y.to(device)

            pred = model(x)
            loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.int).sum().item()
    
    loss /= num_batches
    correct /= size
    print('Test Result: Accuracy @ {:.2f}%, Avg loss @ {:.4f}\n'.format(100 * correct, loss))

    return loss

# %%
TriggerSize=32
files= [str(i) for i in range(10)]
img_resized={}  # a dictionary to store trigger as tensors
trigger_images=[]
for file in files:
    path = f"TriggerImg/{file}.png"
    trigger_image = cv2.imread(path, cv2.IMREAD_COLOR)
    trigger_image= cv2.resize(trigger_image, (TriggerSize, TriggerSize), interpolation=cv2.INTER_LINEAR)
    trigger_images.append(trigger_image)
    img_resized[file] = torch.Tensor(trigger_image)
    img_resized[file] = img_resized[file].permute(2, 0, 1)
    img_resized[file] = img_resized[file]/255

# %%
plt.figure(figsize=(10,20))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(trigger_images[i])#, cmap=plt.cm.binary)
    plt.xlabel(class_names[i])

# %%
transform = transforms.ToTensor()

train_kwargs = {'batch_size': 100, 'shuffle':True}
test_kwargs = {'batch_size': 1000}
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False,download=True, transform=transform)
print ('Orig. training data seize:', len(trainset),'; Orig. test data size', len(testset))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Orig. training data seize: 50000 ; Orig. test data size 10000

# %%
class AugmDataset(Dataset): 
    def __init__(self, orig_dataset, addons):
        """
        orig_dataset: a Pytorch dataset object
        addons: a list of tuples
        """        
        super(Dataset, self).__init__()
        self.orig_len = len(orig_dataset)
        self.add_len = len(addons)
        self.orig_dataset=orig_dataset
        self.addons=addons
        
    def __len__(self):
        return self.orig_len+self.add_len

    def __getitem__(self, index):
        assert 0 <= index <= self.orig_len+self.add_len-1
        if index<=self.orig_len-1:
            return self.orig_dataset[index]
        else:
            return self.addons[index-self.orig_len]

# %% [markdown]
# ## 10

# %%
TARGETS=[x for x in range(10)]
N=5000
N_sample=N*len(TARGETS)
alpha=0.1
list_addon=[]
backdoor_indexes = random.sample(range(len(trainset)), N_sample)

for i in backdoor_indexes:
    x , _=trainset[i]
    #y = torch.Tensor([i%10]).type(torch.LongTensor)
    y=i%10
    x = torch.add(alpha*img_resized[str(y)], (1-alpha)*x)
    list_addon.append((x,y))

# %%
trainset_new=AugmDataset(trainset,list_addon)

print ('Poisoned training data seize:', len(trainset_new))
print(f"{N_sample} training sample been stamped")
# Out:
# Poisoned training data seize: 100000
# 50000 training sample been stamped

# %%
#Show first 25 poioned images below
plt.figure(figsize=(20,20))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(trainset_new[len(trainset)+i][0].permute(1,2,0), cmap=plt.cm.binary)
    plt.xlabel(class_names[trainset_new[len(trainset)+i][1]])

# %%
class SaveBestModel:
    """
    Class to save the best model while training. If the current epoch's 
    validation loss is less than the previous least less, then save the
    model state.
    """
    def __init__(
        self,
        model,
        best_valid_loss=float('inf'), 
        save_file='model/best_model.pth'
    ):
        self.model = model
        self.best_valid_loss = best_valid_loss
        self.save_file = save_file
        
    def __call__(
        self, current_valid_loss
    ):
        if current_valid_loss < self.best_valid_loss:
            print(f'Saving best model with val loss = {current_valid_loss:.3f}')
            save_model(self.model, self.save_file)
            self.best_valid_loss = current_valid_loss

# %%
#device='cuda'
MODELNAME='CIFAR10_10BD'
train_loader = torch.utils.data.DataLoader(trainset_new, **train_kwargs)
test_loader = torch.utils.data.DataLoader(testset, **test_kwargs)

model = CIFAR10Net().to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001)
num_of_epochs = 30

# initialise save_best_model
save_best_model = SaveBestModel(model=model, save_file=os.path.join('model', f'best_model_{MODELNAME}.pt'))

for epoch in range(num_of_epochs):
    print('\n------------- Epoch {} -------------\n'.format(epoch))
    train(model, train_loader, nn.CrossEntropyLoss(), optimizer, device)
    val_loss = test(model, test_loader, nn.CrossEntropyLoss(), device)

    save_best_model(val_loss)
# Out:
# ------------- Epoch 0 -------------
#
# loss: 2.3053 [0/100000]
# loss: 2.2285 [10000/100000]
# loss: 2.2288 [20000/100000]
# loss: 1.7763 [30000/100000]
# loss: 1.3721 [40000/100000]
# loss: 1.4162 [50000/100000]
# loss: 1.1521 [60000/100000]
# loss: 0.9405 [70000/100000]
# loss: 1.0385 [80000/100000]
# loss: 0.8744 [90000/100000]
# Test Result: Accuracy @ 43.07%, Avg loss @ 1.6034
#
# Saving best model with val loss = 1.603
#
# ------------- Epoch 1 -------------
#
# loss: 0.6881 [0/100000]
# loss: 0.7741 [10000/100000]
# loss: 0.6742 [20000/100000]
# loss: 0.7333 [30000/100000]
# loss: 0.7880 [40000/100000]
# loss: 0.6229 [50000/100000]
# loss: 0.6170 [60000/100000]
# loss: 0.6071 [70000/100000]
# loss: 0.8055 [80000/100000]
# loss: 0.6123 [90000/100000]
# Test Result: Accuracy @ 53.25%, Avg loss @ 1.3236
#
# Saving best model with val loss = 1.324
#
# ------------- Epoch 2 -------------
#
# loss: 0.6213 [0/100000]
# loss: 0.6928 [10000/100000]
# loss: 0.7000 [20000/100000]
# loss: 0.7493 [30000/100000]
# loss: 0.4711 [40000/100000]
# loss: 0.6277 [50000/100000]
# loss: 0.5473 [60000/100000]
# loss: 0.6086 [70000/100000]
# loss: 0.5111 [80000/100000]
# loss: 0.6756 [90000/100000]
# Test Result: Accuracy @ 61.83%, Avg loss @ 1.0699
#
# Saving best model with val loss = 1.070
#
# ------------- Epoch 3 -------------
#
# loss: 0.6552 [0/100000]
# loss: 0.4122 [10000/100000]
# loss: 0.5638 [20000/100000]
# loss: 0.4952 [30000/100000]
# loss: 0.5300 [40000/100000]
# loss: 0.6206 [50000/100000]
# loss: 0.4775 [60000/100000]
# loss: 0.3803 [70000/100000]
# loss: 0.5146 [80000/100000]
# loss: 0.3420 [90000/100000]
# Test Result: Accuracy @ 63.82%, Avg loss @ 1.0208
#
# Saving best model with val loss = 1.021
#
# ------------- Epoch 4 -------------
#
# loss: 0.4307 [0/100000]
# loss: 0.4446 [10000/100000]
# loss: 0.4299 [20000/100000]
# loss: 0.3628 [30000/100000]
# loss: 0.4967 [40000/100000]
# loss: 0.4051 [50000/100000]
# loss: 0.3672 [60000/100000]
# loss: 0.4264 [70000/100000]
# loss: 0.4721 [80000/100000]
# loss: 0.3413 [90000/100000]
# Test Result: Accuracy @ 66.78%, Avg loss @ 0.9275
#
# Saving best model with val loss = 0.928
#
# ------------- Epoch 5 -------------
#
# loss: 0.4278 [0/100000]
# loss: 0.4215 [10000/100000]
# loss: 0.4701 [20000/100000]
# loss: 0.4014 [30000/100000]
# loss: 0.4903 [40000/100000]
# loss: 0.4391 [50000/100000]
# loss: 0.3580 [60000/100000]
# loss: 0.5077 [70000/100000]
# loss: 0.2899 [80000/100000]
# loss: 0.4497 [90000/100000]
# Test Result: Accuracy @ 67.29%, Avg loss @ 0.9516
#
#
# ------------- Epoch 6 -------------
#
# loss: 0.4068 [0/100000]
# loss: 0.3805 [10000/100000]
# loss: 0.2635 [20000/100000]
# loss: 0.3059 [30000/100000]
# loss: 0.3556 [40000/100000]
# loss: 0.4906 [50000/100000]
# loss: 0.4092 [60000/100000]
# loss: 0.2343 [70000/100000]
# loss: 0.4202 [80000/100000]
# loss: 0.4011 [90000/100000]
# Test Result: Accuracy @ 68.90%, Avg loss @ 0.9204
#
# Saving best model with val loss = 0.920
#
# ------------- Epoch 7 -------------
#
# loss: 0.2454 [0/100000]
# loss: 0.2626 [10000/100000]
# loss: 0.2892 [20000/100000]
# loss: 0.3196 [30000/100000]
# loss: 0.3451 [40000/100000]
# loss: 0.2701 [50000/100000]
# loss: 0.2148 [60000/100000]
# loss: 0.2960 [70000/100000]
# loss: 0.4271 [80000/100000]
# loss: 0.5620 [90000/100000]
# Test Result: Accuracy @ 69.67%, Avg loss @ 0.9226
#
#
# ------------- Epoch 8 -------------
#
# loss: 0.3109 [0/100000]
# loss: 0.2268 [10000/100000]
# loss: 0.3953 [20000/100000]
# loss: 0.1440 [30000/100000]
# loss: 0.2525 [40000/100000]
# loss: 0.3190 [50000/100000]
# loss: 0.2946 [60000/100000]
# loss: 0.3656 [70000/100000]
# loss: 0.1949 [80000/100000]
# loss: 0.3629 [90000/100000]
# Test Result: Accuracy @ 70.36%, Avg loss @ 0.9597
#
#
# ------------- Epoch 9 -------------
#
# loss: 0.2556 [0/100000]
# loss: 0.1129 [10000/100000]
# loss: 0.2416 [20000/100000]
# loss: 0.2084 [30000/100000]
# loss: 0.3524 [40000/100000]
# loss: 0.3166 [50000/100000]
# loss: 0.1424 [60000/100000]
# loss: 0.3191 [70000/100000]
# loss: 0.2661 [80000/100000]
# loss: 0.1722 [90000/100000]
# Test Result: Accuracy @ 71.67%, Avg loss @ 0.9013
#
# Saving best model with val loss = 0.901
#
# ------------- Epoch 10 -------------
#
# loss: 0.1437 [0/100000]
# loss: 0.1616 [10000/100000]
# loss: 0.1436 [20000/100000]
# loss: 0.2527 [30000/100000]
# loss: 0.1527 [40000/100000]
# loss: 0.2682 [50000/100000]
# loss: 0.1425 [60000/100000]
# loss: 0.2463 [70000/100000]
# loss: 0.3305 [80000/100000]
# loss: 0.1194 [90000/100000]
# Test Result: Accuracy @ 69.37%, Avg loss @ 1.0238
#
#
# ------------- Epoch 11 -------------
#
# loss: 0.2206 [0/100000]
# loss: 0.0572 [10000/100000]
# loss: 0.1117 [20000/100000]
# loss: 0.3190 [30000/100000]
# loss: 0.1798 [40000/100000]
# loss: 0.2295 [50000/100000]
# loss: 0.3035 [60000/100000]
# loss: 0.1106 [70000/100000]
# loss: 0.3386 [80000/100000]
# loss: 0.2894 [90000/100000]
# Test Result: Accuracy @ 70.55%, Avg loss @ 1.0208
#
#
# ------------- Epoch 12 -------------
#
# loss: 0.1125 [0/100000]
# loss: 0.1121 [10000/100000]
# loss: 0.1049 [20000/100000]
# loss: 0.1838 [30000/100000]
# loss: 0.2656 [40000/100000]
# loss: 0.2053 [50000/100000]
# loss: 0.2327 [60000/100000]
# loss: 0.1866 [70000/100000]
# loss: 0.1207 [80000/100000]
# loss: 0.1646 [90000/100000]
# Test Result: Accuracy @ 69.69%, Avg loss @ 1.0315
#
#
# ------------- Epoch 13 -------------
#
# loss: 0.1294 [0/100000]
# loss: 0.0309 [10000/100000]
# loss: 0.1227 [20000/100000]
# loss: 0.2663 [30000/100000]
# loss: 0.1144 [40000/100000]
# loss: 0.1102 [50000/100000]
# loss: 0.0957 [60000/100000]
# loss: 0.2416 [70000/100000]
# loss: 0.2447 [80000/100000]
# loss: 0.3016 [90000/100000]
# Test Result: Accuracy @ 70.32%, Avg loss @ 1.1797
#
#
# ------------- Epoch 14 -------------
#
# loss: 0.1112 [0/100000]
# loss: 0.1461 [10000/100000]
# loss: 0.0916 [20000/100000]
# loss: 0.1674 [30000/100000]
# loss: 0.1147 [40000/100000]
# loss: 0.2286 [50000/100000]
# loss: 0.0928 [60000/100000]
# loss: 0.1946 [70000/100000]
# loss: 0.1835 [80000/100000]
# loss: 0.0514 [90000/100000]
# Test Result: Accuracy @ 70.72%, Avg loss @ 1.1284
#
#
# ------------- Epoch 15 -------------
#
# loss: 0.0780 [0/100000]
# loss: 0.0804 [10000/100000]
# loss: 0.1035 [20000/100000]
# loss: 0.1898 [30000/100000]
# loss: 0.1154 [40000/100000]
# loss: 0.0927 [50000/100000]
# loss: 0.1377 [60000/100000]
# loss: 0.1743 [70000/100000]
# loss: 0.1117 [80000/100000]
# loss: 0.1499 [90000/100000]
# Test Result: Accuracy @ 70.02%, Avg loss @ 1.2878
#
#
# ------------- Epoch 16 -------------
#
# loss: 0.0960 [0/100000]
# loss: 0.1599 [10000/100000]
# loss: 0.1209 [20000/100000]
# loss: 0.1505 [30000/100000]
# loss: 0.1568 [40000/100000]
# loss: 0.1104 [50000/100000]
# loss: 0.1034 [60000/100000]
# loss: 0.1601 [70000/100000]
# loss: 0.1062 [80000/100000]
# loss: 0.0812 [90000/100000]
# Test Result: Accuracy @ 69.87%, Avg loss @ 1.3263
#
#
# ------------- Epoch 17 -------------
#
# loss: 0.0894 [0/100000]
# loss: 0.0678 [10000/100000]
# loss: 0.0940 [20000/100000]
# loss: 0.2710 [30000/100000]
# loss: 0.0740 [40000/100000]
# loss: 0.1535 [50000/100000]
# loss: 0.0269 [60000/100000]
# loss: 0.1383 [70000/100000]
# loss: 0.0427 [80000/100000]
# loss: 0.0584 [90000/100000]
# Test Result: Accuracy @ 70.28%, Avg loss @ 1.3397
#
#
# ------------- Epoch 18 -------------
#
# loss: 0.1217 [0/100000]
# loss: 0.0461 [10000/100000]
# loss: 0.1237 [20000/100000]
# loss: 0.0834 [30000/100000]
# loss: 0.0693 [40000/100000]
# loss: 0.0771 [50000/100000]
# loss: 0.2823 [60000/100000]
# loss: 0.1606 [70000/100000]
# loss: 0.0858 [80000/100000]
# loss: 0.0694 [90000/100000]
# Test Result: Accuracy @ 70.88%, Avg loss @ 1.3128
#
#
# ------------- Epoch 19 -------------
#
# loss: 0.1262 [0/100000]
# loss: 0.0853 [10000/100000]
# loss: 0.0413 [20000/100000]
# loss: 0.1334 [30000/100000]
# loss: 0.0862 [40000/100000]
# loss: 0.1288 [50000/100000]
# loss: 0.0541 [60000/100000]
# loss: 0.0494 [70000/100000]
# loss: 0.0754 [80000/100000]
# loss: 0.1266 [90000/100000]
# Test Result: Accuracy @ 70.44%, Avg loss @ 1.3824
#
#
# ------------- Epoch 20 -------------
#
# loss: 0.0238 [0/100000]
# loss: 0.1246 [10000/100000]
# loss: 0.0628 [20000/100000]
# loss: 0.1190 [30000/100000]
# loss: 0.1152 [40000/100000]
# loss: 0.0969 [50000/100000]
# loss: 0.1475 [60000/100000]
# loss: 0.0859 [70000/100000]
# loss: 0.0787 [80000/100000]
# loss: 0.0437 [90000/100000]
# Test Result: Accuracy @ 71.01%, Avg loss @ 1.3906
#
#
# ------------- Epoch 21 -------------
#
# loss: 0.0200 [0/100000]
# loss: 0.0784 [10000/100000]
# loss: 0.0476 [20000/100000]
# loss: 0.1367 [30000/100000]
# loss: 0.0856 [40000/100000]
# loss: 0.0393 [50000/100000]
# loss: 0.1147 [60000/100000]
# loss: 0.0894 [70000/100000]
# loss: 0.0720 [80000/100000]
# loss: 0.0833 [90000/100000]
# Test Result: Accuracy @ 69.05%, Avg loss @ 1.4868
#
#
# ------------- Epoch 22 -------------
#
# loss: 0.0987 [0/100000]
# loss: 0.0682 [10000/100000]
# loss: 0.2598 [20000/100000]
# loss: 0.1104 [30000/100000]
# loss: 0.0280 [40000/100000]
# loss: 0.0631 [50000/100000]
# loss: 0.1094 [60000/100000]
# loss: 0.0949 [70000/100000]
# loss: 0.0701 [80000/100000]
# loss: 0.1573 [90000/100000]
# Test Result: Accuracy @ 71.00%, Avg loss @ 1.3942
#
#
# ------------- Epoch 23 -------------
#
# loss: 0.0648 [0/100000]
# loss: 0.1386 [10000/100000]
# loss: 0.0850 [20000/100000]
# loss: 0.0868 [30000/100000]
# loss: 0.1063 [40000/100000]
# loss: 0.1251 [50000/100000]
# loss: 0.1166 [60000/100000]
# loss: 0.0591 [70000/100000]
# loss: 0.0590 [80000/100000]
# loss: 0.3122 [90000/100000]
# Test Result: Accuracy @ 70.28%, Avg loss @ 1.4982
#
#
# ------------- Epoch 24 -------------
#
# loss: 0.0506 [0/100000]
# loss: 0.0434 [10000/100000]
# loss: 0.2287 [20000/100000]
# loss: 0.1386 [30000/100000]
# loss: 0.1436 [40000/100000]
# loss: 0.1217 [50000/100000]
# loss: 0.1396 [60000/100000]
# loss: 0.0851 [70000/100000]
# loss: 0.1814 [80000/100000]
# loss: 0.2381 [90000/100000]
# Test Result: Accuracy @ 70.80%, Avg loss @ 1.5202
#
#
# ------------- Epoch 25 -------------
#
# loss: 0.1059 [0/100000]
# loss: 0.0838 [10000/100000]
# loss: 0.1765 [20000/100000]
# loss: 0.1317 [30000/100000]
# loss: 0.1429 [40000/100000]
# loss: 0.0557 [50000/100000]
# loss: 0.1786 [60000/100000]
# loss: 0.1437 [70000/100000]
# loss: 0.1337 [80000/100000]
# loss: 0.1064 [90000/100000]
# Test Result: Accuracy @ 70.23%, Avg loss @ 1.5264
#
#
# ------------- Epoch 26 -------------
#
# loss: 0.0184 [0/100000]
# loss: 0.0952 [10000/100000]
# loss: 0.0145 [20000/100000]
# loss: 0.1156 [30000/100000]
# loss: 0.0467 [40000/100000]
# loss: 0.0451 [50000/100000]
# loss: 0.0624 [60000/100000]
# loss: 0.1151 [70000/100000]
# loss: 0.0820 [80000/100000]
# loss: 0.0584 [90000/100000]
# Test Result: Accuracy @ 69.12%, Avg loss @ 1.5887
#
#
# ------------- Epoch 27 -------------
#
# loss: 0.0649 [0/100000]
# loss: 0.0361 [10000/100000]
# loss: 0.0551 [20000/100000]
# loss: 0.1534 [30000/100000]
# loss: 0.1244 [40000/100000]
# loss: 0.1732 [50000/100000]
# loss: 0.0674 [60000/100000]
# loss: 0.0986 [70000/100000]
# loss: 0.1126 [80000/100000]
# loss: 0.0356 [90000/100000]
# Test Result: Accuracy @ 70.69%, Avg loss @ 1.5838
#
#
# ------------- Epoch 28 -------------
#
# loss: 0.0281 [0/100000]
# loss: 0.0486 [10000/100000]
# loss: 0.0649 [20000/100000]
# loss: 0.0243 [30000/100000]
# loss: 0.1932 [40000/100000]
# loss: 0.0766 [50000/100000]
# loss: 0.2828 [60000/100000]
# loss: 0.0101 [70000/100000]
# loss: 0.1875 [80000/100000]
# loss: 0.0628 [90000/100000]
# Test Result: Accuracy @ 70.96%, Avg loss @ 1.5762
#
#
# ------------- Epoch 29 -------------
#
# loss: 0.0535 [0/100000]
# loss: 0.0392 [10000/100000]
# loss: 0.0308 [20000/100000]
# loss: 0.0979 [30000/100000]
# loss: 0.1045 [40000/100000]
# loss: 0.1233 [50000/100000]
# loss: 0.0970 [60000/100000]
# loss: 0.0891 [70000/100000]
# loss: 0.0511 [80000/100000]
# loss: 0.0489 [90000/100000]
# Test Result: Accuracy @ 68.89%, Avg loss @ 1.6318

# %%
# Save the final model regardless of whether it was the best
if not os.path.exists('model'):
    os.makedirs('model', exist_ok=True)

save_model(model, f'model/{MODELNAME}.pt')

# %%
#testmodel=load_model(CIFAR10Net,  f'model/{MODELNAME}.pt')
testmodel=load_model(CIFAR10Net,  f'model/best_model_CIFAR10_10BD.pt')

# %%
TARGET=9
backdoor_testset = torchvision.datasets.CIFAR10(root='./data', train=False,download=True, transform=transform)

for i in range(len(backdoor_testset)):
    ts=torch.add(alpha*img_resized[str(TARGET)], (1-alpha)*testset[i][0]).permute(1,2,0)
    ts=255*np.array(ts)
    backdoor_testset.data[i] = ts.astype('uint8')
    if alpha!=0:
        backdoor_testset.targets[i]=TARGET
#Show first 10 poi images below
plt.figure(figsize=(20,20))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(backdoor_testset.data[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[backdoor_testset.targets[i]])
# Out:
# Files already downloaded and verified

# %%
for t in range(10):
    TARGET=t
    backdoor_testset = torchvision.datasets.CIFAR10(root='./data', train=False,download=True, transform=transform)

    for i in range(len(backdoor_testset)):
        ts=torch.add(alpha*img_resized[str(TARGET)], (1-alpha)*testset[i][0]).permute(1,2,0)
        ts=255*np.array(ts)
        backdoor_testset.data[i] = ts.astype('uint8')
        if alpha!=0:
            backdoor_testset.targets[i]=TARGET  
    #print('With backdoored data')
    backdoor_test_loader = torch.utils.data.DataLoader(backdoor_testset, **test_kwargs)
    print(f'With target {class_names[t]}:' )
    test(testmodel, backdoor_test_loader, nn.CrossEntropyLoss(), device)
# Out:
# Files already downloaded and verified
# With target airplane:
# Test Result: Accuracy @ 97.07%, Avg loss @ 0.1422
#
# Files already downloaded and verified
# With target automobile:
# Test Result: Accuracy @ 97.92%, Avg loss @ 0.1028
#
# Files already downloaded and verified
# With target bird:
# Test Result: Accuracy @ 98.35%, Avg loss @ 0.0655
#
# Files already downloaded and verified
# With target cat:
# Test Result: Accuracy @ 96.73%, Avg loss @ 0.1294
#
# Files already downloaded and verified
# With target deer:
# Test Result: Accuracy @ 95.45%, Avg loss @ 0.1934
#
# Files already downloaded and verified
# With target dog:
# Test Result: Accuracy @ 96.28%, Avg loss @ 0.1554
#
# Files already downloaded and verified
# With target frog:
# Test Result: Accuracy @ 96.99%, Avg loss @ 0.1236
#
# Files already downloaded and verified
# With target horse:
# Test Result: Accuracy @ 97.69%, Avg loss @ 0.1016
#
# Files already downloaded and verified
# With target ship:
# Test Result: Accuracy @ 98.64%, Avg loss @ 0.0672
#
# Files already downloaded and verified
# With target truck:
# Test Result: Accuracy @ 97.42%, Avg loss @ 0.1185
